# %%
# Dataset credit: CICIDS2017
# Iman Sharafaldin, Arash Habibi Lashkari, and Ali A. Ghorbani, “Toward Generating a New Intrusion Detection Dataset and Intrusion Traffic Characterization”, 4th International Conference on Information Systems Security and Privacy (ICISSP), Portugal, January 2018

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('ids_2017_concat.csv')

# %%
df = df.drop(columns='DestinationPort')

# %%
# 2.8M rows, 79 cols
df.shape
df
# Out:
#          FlowDuration  TotalFwdPackets  TotalBackwardPackets  \
# 0                   3                2                     0
# 1                 109                1                     1
# 2                  52                1                     1
# 3                  34                1                     1
# 4                   3                2                     0
# ...               ...              ...                   ...
# 2830738         32215                4                     2
# 2830739           324                2                     2
# 2830740            82                2                     1
# 2830741       1048635                6                     2
# 2830742         94939                4                     2
#
#          TotalLengthofFwdPackets  TotalLengthofBwdPackets  FwdPacketLengthMax  \
# 0                             12                        0                   6
# 1                              6                        6                   6
# 2                              6                        6                   6
# 3                              6                        6                   6
# 4                             12                        0                   6
# ...                          ...                      ...                 ...
# 2830738                      112                      152                  28
# 2830739                       84                      362                  42
# 2830740                       31                        6                  31
# 2830741                      192                      256                  32
# 2830742                      188                      226                  47
#
#          FwdPacketLengthMin  FwdPacketLengthMean  FwdPacketLengthStd  \
# 0                         6                  6.0             0.00000
# 1                         6                  6.0             0.00000
# 2                         6                  6.0             0.00000
# 3                         6                  6.0             0.00000
# 4                         6                  6.0             0.00000
# ...                     ...                  ...                 ...
# 2830738                  28                 28.0             0.00000
# 2830739                  42                 42.0             0.00000
# 2830740                   0                 15.5            21.92031
# 2830741                  32                 32.0             0.00000
# 2830742                  47                 47.0             0.00000
#
#          BwdPacketLengthMax  ...  min_seg_size_forward  ActiveMean  ActiveStd  \
# 0                         0  ...                    20         0.0        0.0
# 1                         6  ...                    20         0.0        0.0
# 2                         6  ...                    20         0.0        0.0
# 3                         6  ...                    20         0.0        0.0
# 4                         0  ...                    20         0.0        0.0
# ...                     ...  ...                   ...         ...        ...
# 2830738                  76  ...                    20         0.0        0.0
# 2830739                 181  ...                    20         0.0        0.0
# 2830740                   6  ...                    32         0.0        0.0
# 2830741                 128  ...                    20         0.0        0.0
# 2830742                 113  ...                    20         0.0        0.0
#
#          ActiveMax  ActiveMin  IdleMean  IdleStd  IdleMax  IdleMin   Label
# 0                0          0       0.0      0.0        0        0  BENIGN
# 1                0          0       0.0      0.0        0        0  BENIGN
# 2                0          0       0.0      0.0        0        0  BENIGN
# 3                0          0       0.0      0.0        0        0  BENIGN
# 4                0          0       0.0      0.0        0        0  BENIGN
# ...            ...        ...       ...      ...      ...      ...     ...
# 2830738          0          0       0.0      0.0        0        0  BENIGN
# 2830739          0          0       0.0      0.0        0        0  BENIGN
# 2830740          0          0       0.0      0.0        0        0  BENIGN
# 2830741          0          0       0.0      0.0        0        0  BENIGN
# 2830742          0          0       0.0      0.0        0        0  BENIGN
#
# [2830743 rows x 78 columns]

# %%
# 15 unique labels
labels = df['Label'].unique()

columns = df.columns

labels
# Out:
# array(['BENIGN', 'DDoS', 'PortScan', 'Bot', 'Infiltration',
#        'WebAttack�BruteForce', 'WebAttack�XSS', 'WebAttack�SqlInjection',
#        'FTP-Patator', 'SSH-Patator', 'DoSslowloris', 'DoSSlowhttptest',
#        'DoSHulk', 'DoSGoldenEye', 'Heartbleed'], dtype=object)

# %%
# explore values
for column in columns:
    print(column, " ", df[column].unique())
# Out:
# FlowDuration   [       3      109       52 ... 11509095 11512230  1048635]
# TotalFwdPackets   [   2    1    3 ... 6969 1158 9951]
# TotalBackwardPackets   [    0     1     2 ...  4591  1029 14759]
# TotalLengthofFwdPackets   [   12     6    37 ... 35380 33901 10775]
# TotalLengthofBwdPackets   [     0      6    176 ...  74438 147609 267793]
# FwdPacketLengthMax   [   6   31    0 ... 4204 3618 3419]
# FwdPacketLengthMin   [   6    0   31   37   41   46   34   35   40   32   36   48   50   45
#    43   47   60   54   55   52   56   59   51   65   49   38   74   78
#    39   58   81   66   57   62   53   42   61   44   75   64   82   77
#    84   80   73   94   79   71   29   30   63   27   67   28   33   70
#    83   68   88   76   69   99   92   23  247  188  235  216  165   85
#   201   26  187   89   90  108   93   96   97   87   98   72   86  214
#   233   18 1472  252  178  176  250  174  248   22   24   12  930  421
#   940  526  110   95 1375  164  163  319 1017  929  696  913 1016  914
#   931  118  207  206  927  208  814  943  925  695  928  948  325 1176
#   957 1014  935    5  101  256  182   91   25  102  100  249  112  123
#  1019  280  982  519  763 1460  862  932  926  919  937  105  138  258
#   251    2  917 1232 1398  341  545 1418  140 1263   19  126  103  127
#   181  238 1312 1326 1336 1346  172  253  254 1316  236  170 1330  137
#   133  180  151 1397  143   20  431  147  145 1342 1003  104 1458  173
#   565  817 1399  912  357  212 1130  274 1448  129 1401  692    7 2325
#   115  517  837  128  242  191  515  641  157 1354 1160  194  237  210
#   581  890  307  355  419  483  222 1321 2065  629   17  458  891  790
#   845 1082 1196  272 1255  282 2293  556  259  908  962  979  909  960
#   964  496  857  661 1350 1370 1430 1315 1329  124 1296  155  998  266
#   230  132  916  924  883  229 1408  152  300  323  499   14    1 1368
#   193  981 1429  352  444  192 1120 1002  942  592 1729 1629 1420 1157
#    16  405  316 1435  453  861    9  441  576  603  528  141 1332  808
#  1257  106   15 1054  177 1417  313 1396 1493 1372  232  255  244  751
#   309 1038  231  968    8 1195 1115 1060 1094  974 1021  987 1089 1085
#   681  239  356  520  351 1983  389  524  530  531  533  535   11  414
#   107 1155 1295  131  680  713 1212 1268 1244 1230 1236 1233 1213 1258
#  1240 1189 1177 1231 1185 1276  117  617  901  500 1452  621  261 1436
#  1317  119 1432  552  437  392]
# FwdPacketLengthMean   [   6.           18.5          14.33333333 ...  496.625      1098.8
#   897.9166667 ]
# FwdPacketLengthStd   [   0.           17.67766953   14.43375673 ...  684.1860649   232.638131
#  1520.026343  ]
# BwdPacketLengthMax   [    0     6    88 ...  4690 17376 15928]
# BwdPacketLengthMin   [   0    6   88  100    4   46   69  150   50   99   53  230  151  145
#   163   98  102  123  164   48  103   61  110   68   92   70  134   41
#  939.6923077 ]
# PacketLengthStd   [   0.           14.43375673   12.5        ...  720.8822751  3216.69083
#  1857.187221  ]
# PacketLengthVariance   [0.00000000e+00 2.08333333e+02 1.56250000e+02 ... 3.84301314e+06
#  5.19671254e+05 3.44914437e+06]
# FINFlagCount   [0 1]
# SYNFlagCount   [0 1]
# RSTFlagCount   [0 1]
# PSHFlagCount   [0 1]
# ACKFlagCount   [1 0]
# URGFlagCount   [0 1]
# CWEFlagCount   [0 1]
# ECEFlagCount   [0 1]
# DownUpRatio   [  0   1   2   3   5   4   6   7  16   8 124  11  12 108  29  74  90  25
#   27  32  20 156  21  10  43   9  28  14  35  39  26]
# AveragePacketSize   [   9.           34.           16.33333333 ...  341.1538462   717.2173913
#  1018.        ]
# AvgFwdSegmentSize   [   6.           18.5          14.33333333 ...  496.625      1098.8
#   897.9166667 ]
# AvgBwdSegmentSize   [   0.           6.          88.        ... 1968.12       226.1111111
#   995.5130112]
# FwdHeaderLength.1   [    40     20     60 ...  59256  31708 201504]
# FwdAvgBytesBulk   [0]
# FwdAvgPacketsBulk   [0]
# FwdAvgBulkRate   [0]
# BwdAvgBytesBulk   [0]
# BwdAvgPacketsBulk   [0]
# BwdAvgBulkRate   [0]
# SubflowFwdPackets   [   2    1    3 ... 6969 1158 9951]
# SubflowFwdBytes   [   12     6    37 ... 35380 33901 10775]
# SubflowBwdPackets   [    0     1     2 ...  4591  1029 14759]
# SubflowBwdBytes   [     0      6    176 ...  74438 147609 267793]
# Init_Win_bytes_forward   [   33    29    31 ...  2502 13119  5205]
# Init_Win_bytes_backward   [   -1   256   329 ...  9414 28835 62785]
# act_data_pkt_fwd   [   1    0    2 ... 6337 2901 9743]
# min_seg_size_forward   [        20         32         28         40          0         44
#          52         24         60          6         48         10
#          56         38         46         31          8  -83885313
#          12         93         78        126         36         14
#  -536870661 -536870660        138         -1]
# ActiveMean   [      0.   46735. 3591908. ... 3000526.   16944.  379019.]
# ActiveStd   [      0.      1296391.188    166172.922   ...   36364.33334  228449.7222
#    39823.09506]
# ActiveMax   [      0   46735 3591908 ...   16944  379019  119807]
# ActiveMin   [      0   46735 3591908 ... 3000526   16944  379019]
# IdleMean   [       0. 30900000.  7114425. ...  6503248.  6504954.  6506213.]
# IdleStd   [       0.      12900000.        140678.187   ...  9879172.026
#   2116770.738      20713.30669]
# IdleMax   [       0 30900000  7114425 ...  6503248  6504954  6506213]
# IdleMin   [       0 30900000  7114425 ...  6503248  6504954  6506213]
# Label   ['BENIGN' 'DDoS' 'PortScan' 'Bot' 'Infiltration' 'WebAttack�BruteForce'
#  'WebAttack�XSS' 'WebAttack�SqlInjection' 'FTP-Patator' 'SSH-Patator'
#  'DoSslowloris' 'DoSSlowhttptest' 'DoSHulk' 'DoSGoldenEye' 'Heartbleed']

# %%
# missing values? FlowBytes/s - 1358
for column in columns:
    print(column, ": ", df[column].isnull().values.any(), ", total: ", df[column].isnull().sum())
# Out:
# FlowDuration :  False , total:  0
# # Exploring the dataset class composition & preparing the dataset
#
# Below, the class distribution is calculated and coincides with the authors' findings.

# %%
(c, count) = np.unique(df['Label'], return_counts=True)

for i in range(len(c)):
    print(c[i], ": ", "{:.3f}".format((count[i]/df.shape[0] * 100)),"%")
# Out:
# BENIGN :  80.300 %
# Bot :  0.069 %
# DDoS :  4.523 %
# DoSGoldenEye :  0.364 %
# DoSHulk :  8.163 %
# DoSSlowhttptest :  0.194 %
# DoSslowloris :  0.205 %
# FTP-Patator :  0.280 %
# Heartbleed :  0.000 %
# Infiltration :  0.001 %
# PortScan :  5.614 %
# SSH-Patator :  0.208 %
# WebAttack�BruteForce :  0.053 %
# WebAttack�SqlInjection :  0.001 %
# WebAttack�XSS :  0.023 %

# %% [markdown]
# From the paper:
# ```Most neural network models work better with databases with balanced samples in each class. However, neural network models also require a big dataset for better generalization of the task assigned to it. Therefore, it is not feasible to simply trim down the number of samples in the classes with a higher proportion to match with the minority classes. For the best of both worlds, the database is divided into two categories. Namely, the normal attack samples, and minority attack samples```

# %%
# normal and minority attack labels
normal_labels = ['BENIGN','DDoS','DoSGoldenEye','DoSHulk','DoSSlowhttptest','DoSslowloris','PortScan']
minority_labels = ['FTP-Patator','SSH-Patator','Bot','Heartbleed','Infiltration','WebAttack�BruteForce','WebAttack�SqlInjection','WebAttack�XSS']

# %%
# splitting the two sets
normal = df.loc[df['Label'].isin(normal_labels)]
minority = df.loc[df['Label'].isin(minority_labels)]

# %%
# count samples
for label in labels:
    print(label, ": ", df.loc[df['Label']==label].shape[0])
# Out:
# BENIGN :  2273097
# DDoS :  128027
# PortScan :  158930
# Bot :  1966
# Infiltration :  36
# WebAttack�BruteForce :  1507
# WebAttack�XSS :  652
# WebAttack�SqlInjection :  21
# FTP-Patator :  7938
# SSH-Patator :  5897
# DoSslowloris :  5796
# DoSSlowhttptest :  5499
# DoSHulk :  231073
# DoSGoldenEye :  10293
# Heartbleed :  11

# %% [markdown]
# # Inconsistency in BENIGN values - paper has 529,918, my dataset 2,273,097. The paper uses BENIGN samples from the Monday file only.

# %%
# get BENIGN samples from Monday file

df_monday = pd.read_csv('Monday-WorkingHours.pcap_ISCX.csv')
benign_monday = df_monday.loc[df_monday[' Label']=='BENIGN']
# remove space from col name
benign_monday = benign_monday.rename(columns={" Label": "Label"})
# remove destination port
benign_monday = benign_monday.drop(columns=' Destination Port')

# %%
# replace BENIGN in dataset with benign_monday

tmp = df.loc[df['Label'] != 'BENIGN']
frames = [benign_monday, tmp]
df2 = pd.concat(frames)
df2.reset_index(drop=True, inplace=True)

# %%
# count samples
for label in labels:
    print(label, ": ", df2.loc[df2['Label']==label].shape[0])
# Out:
# BENIGN :  529918
# DDoS :  128027
# PortScan :  158930
# Bot :  1966
# Infiltration :  36
# WebAttack�BruteForce :  1507
# WebAttack�XSS :  652
# WebAttack�SqlInjection :  21
# FTP-Patator :  7938
# SSH-Patator :  5897
# DoSslowloris :  5796
# DoSSlowhttptest :  5499
# DoSHulk :  231073
# DoSGoldenEye :  10293
# Heartbleed :  11

# %%
# construct training & test sets

train_labels = [train_benign, train_ftp, train_ssh, train_bot, train_ddos, train_goldeneye, train_hulk, \
    train_slowhttp, train_slowloris, train_heartbleed, train_infiltration, train_portscan, train_bruteforce, \
        train_sql, train_xss
    ]

test_labels = [test_benign, test_ftp, test_ssh, test_bot, test_ddos, test_goldeneye, test_hulk, \
    test_slowhttp, test_slowloris, test_heartbleed, test_infiltration, test_portscan, test_bruteforce, \
        test_sql, test_xss
    ]
# benign
train_benign = df2.loc[df2['Label']=='BENIGN'][:105983]
test_benign = df2.loc[df2['Label']=='BENIGN'][105984:]

# FTP-Patator
train_ftp = df2.loc[df2['Label']=='FTP-Patator'][:6350]
test_ftp = df2.loc[df2['Label']=='FTP-Patator']

# SSH-Patator
train_ssh = df2.loc[df2['Label']=='SSH-Patator'][:4717]
test_ssh = df2.loc[df2['Label']=='SSH-Patator']

# Bot
train_bot = df2.loc[df2['Label']=='Bot'][:1572]
test_bot = df2.loc[df2['Label']=='Bot']

# DDoS
train_ddos = df2.loc[df2['Label']=='DDoS'][:102422]
test_ddos = df2.loc[df2['Label']=='DDoS'][102423:]

# DoS Goldeneye
train_goldeneye = df2.loc[df2['Label']=='DoSGoldenEye'][:4118]
test_goldeneye = df2.loc[df2['Label']=='DoSGoldenEye'][4118:]

# DoS Hulk
train_hulk = df2.loc[df2['Label']=='DoSHulk'][:92430]
test_hulk = df2.loc[df2['Label']=='DoSHulk'][92430:]

# Dos Slowhttptest
train_slowhttp = df2.loc[df2['Label']=='DoSSlowhttptest'][:2200]
test_slowhttp = df2.loc[df2['Label']=='DoSSlowhttptest'][2200:]

# Dos slowloris
train_slowloris = df2.loc[df2['Label']=='DoSslowloris'][:2319]
test_slowloris = df2.loc[df2['Label']=='DoSslowloris'][2319:]

# Heartbleed 
train_heartbleed = df2.loc[df2['Label']=='Heartbleed'][:9]
test_heartbleed = df2.loc[df2['Label']=='Heartbleed']

# Infiltration
train_infiltration = df2.loc[df2['Label']=='Infiltration'][:28]
test_infiltration = df2.loc[df2['Label']=='Infiltration']

# PortScan
train_portscan = df2.loc[df2['Label']=='PortScan'][:103304]
test_portscan = df2.loc[df2['Label']=='PortScan'][103304:]

# BruteForce
train_bruteforce = df2.loc[df2['Label']=='WebAttack�BruteForce'][:1205]
test_bruteforce = df2.loc[df2['Label']=='WebAttack�BruteForce']

# SQL
train_sql = df2.loc[df2['Label']=='WebAttack�SqlInjection'][:16]
test_sql = df2.loc[df2['Label']=='WebAttack�SqlInjection']

# XSS
train_xss = df2.loc[df2['Label']=='WebAttack�XSS'][:521]
test_xss = df2.loc[df2['Label']=='WebAttack�XSS']

train = pd.concat(train_labels)
test = pd.concat(test_labels)

# %%
# missing values? 
for column in columns:
    print(column, ": ", df2[column].isnull().values.any(), ", total: ", df2[column].isnull().sum())
# Out:
# FlowDuration :  True , total:  529918
# TotalFwdPackets :  True , total:  529918
# TotalBackwardPackets :  True , total:  529918
# TotalLengthofFwdPackets :  True , total:  529918
# TotalLengthofBwdPackets :  True , total:  529918
# FwdPacketLengthMax :  True , total:  529918
# FwdPacketLengthMin :  True , total:  529918
# FwdPacketLengthMean :  True , total:  529918
# FwdPacketLengthStd :  True , total:  529918
# BwdPacketLengthMax :  True , total:  529918
# BwdPacketLengthMin :  True , total:  529918
# BwdPacketLengthMean :  True , total:  529918
# BwdPacketLengthStd :  True , total:  529918
# FlowBytess :  True , total:  529918
# FlowPacketss :  True , total:  529918
# FlowIATMean :  True , total:  529918
# FlowIATStd :  True , total:  529918
# FlowIATMax :  True , total:  529918
# FlowIATMin :  True , total:  529918
# FwdIATTotal :  True , total:  529918
# FwdIATMean :  True , total:  529918
# FwdIATStd :  True , total:  529918
# FwdIATMax :  True , total:  529918
# FwdIATMin :  True , total:  529918
# BwdIATTotal :  True , total:  529918
# BwdIATMean :  True , total:  529918
# BwdIATStd :  True , total:  529918
# BwdIATMax :  True , total:  529918
# BwdIATMin :  True , total:  529918
# FwdPSHFlags :  True , total:  529918
# BwdPSHFlags :  True , total:  529918
# FwdURGFlags :  True , total:  529918
# BwdURGFlags :  True , total:  529918
# FwdHeaderLength :  True , total:  529918
# BwdHeaderLength :  True , total:  529918
# FwdPacketss :  True , total:  529918
# BwdPacketss :  True , total:  529918
# MinPacketLength :  True , total:  529918
# MaxPacketLength :  True , total:  529918
# PacketLengthMean :  True , total:  529918
# PacketLengthStd :  True , total:  529918
# PacketLengthVariance :  True , total:  529918
# FINFlagCount :  True , total:  529918
# SYNFlagCount :  True , total:  529918
# RSTFlagCount :  True , total:  529918
# PSHFlagCount :  True , total:  529918
# ACKFlagCount :  True , total:  529918
# URGFlagCount :  True , total:  529918
# CWEFlagCount :  True , total:  529918
# ECEFlagCount :  True , total:  529918
# DownUpRatio :  True , total:  529918
# AveragePacketSize :  True , total:  529918
# AvgFwdSegmentSize :  True , total:  529918
# AvgBwdSegmentSize :  True , total:  529918
# FwdHeaderLength.1 :  True , total:  529918
# FwdAvgBytesBulk :  True , total:  529918
# FwdAvgPacketsBulk :  True , total:  529918
# FwdAvgBulkRate :  True , total:  529918
# BwdAvgBytesBulk :  True , total:  529918
# BwdAvgPacketsBulk :  True , total:  529918
# BwdAvgBulkRate :  True , total:  529918
# SubflowFwdPackets :  True , total:  529918
# SubflowFwdBytes :  True , total:  529918
# SubflowBwdPackets :  True , total:  529918
# SubflowBwdBytes :  True , total:  529918
# Init_Win_bytes_forward :  False , total:  0
# Init_Win_bytes_backward :  True , total:  529918
# act_data_pkt_fwd :  True , total:  529918
# min_seg_size_forward :  True , total:  529918
# ActiveMean :  True , total:  529918
# ActiveStd :  True , total:  529918
# ActiveMax :  True , total:  529918
# ActiveMin :  True , total:  529918
# IdleMean :  True , total:  529918
# IdleStd :  True , total:  529918
# IdleMax :  True , total:  529918
# IdleMin :  True , total:  529918
# Label :  False , total:  0

# %%
# TODO fix concat - merge tmp & df2 without col duplication
df2.shape
# Out:
# (1087564, 154)
